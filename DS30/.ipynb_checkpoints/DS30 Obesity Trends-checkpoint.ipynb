# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# - YearStart & YearEnd : the starting and ending year for which the obesity percentage is to be estimated
# - Sample_Size : the sample of population
# - LocationDesc : the location description and LocationAbbr is the location abbreviation
# - Topic and Question : the topic and question category under which sample population falls
# - Age(years) : the age range to which sample population belong
# - Data_VAlue : the population obesity percentage (the target variable)

# %% [markdown]
# # Train Data

# %%
train_data = pd.read_csv('Train_data.csv')
train_data.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2011     2011           AL      Alabama
# 1       2011     2011           AL      Alabama
# 2       2011     2011           AL      Alabama
# 3       2011     2011           AL      Alabama
# 4       2011     2011           AL      Alabama
#
#                                    Datasource                    Topic  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                                             Question Data_Value_Type  \
# 0  Percent of adults aged 18 years and older who ...           Value
# 1  Percent of adults aged 18 years and older who ...           Value
# ...

# %%
train_data.describe()
# Out:
#           YearStart       YearEnd    Data_Value  Low_Confidence_Limit  \
# count  52345.000000  52345.000000  52345.000000          52345.000000
# mean    2012.321081   2012.321081     31.356217             27.114031
# std        1.101964      1.101964      9.797423              9.590796
# min     2011.000000   2011.000000      0.900000              0.300000
# 25%     2011.000000   2011.000000     24.382296             20.300000
# 50%     2013.000000   2013.000000     31.128517             26.900000
# 75%     2013.000000   2013.000000     37.423078             33.333449
# max     2014.000000   2014.000000     75.300000             69.500000
#
#        High_Confidence_Limit     Sample_Size    LocationID
# count            52345.000000   52345.000000  52345.000000
# mean                36.155544    4021.174215     29.698182
# std                 10.806611   20315.596445     16.042853
# min                  3.000000      50.000000      1.000000
# ...

# %%
lake_test = train_data[['Low_Confidence_Limit', 'Data_Value', 'High_Confidence_Limit ']].copy()
lake_test['lake_pred'] = (lake_test['Low_Confidence_Limit'] + lake_test['High_Confidence_Limit '])/2
lake_test.head(10)
# Out:
#    Low_Confidence_Limit  Data_Value  High_Confidence_Limit   lake_pred
# 0                  30.5        32.0                    33.5      32.00
# 1                  29.9        32.3                    34.7      32.30
# 2                  30.0        31.8                    33.6      31.80
# 3                  29.9        33.6                    37.6      33.75
# 4                  30.2        32.8                    35.6      32.90
# 5                  31.0        33.8                    36.8      33.90
# 6                  23.7        26.4                    29.3      26.50
# 7                  12.6        16.3                    20.9      16.75
# 8                  30.7        35.2                    40.0      35.35
# 9                  31.6        35.5                    39.6      35.60

# %% [markdown]
# Al parecer hay una especia de datalake, ya que en los datos de testeo se encuentra los limites de confianza

# %% [markdown]
# # Test Data

# %%
def submit(preds, name_pred):
    data_pred = pd.DataFrame(preds, columns = ['prediction'])
    data_pred.to_csv('%s.csv'%(name_pred))
    return ('Csv Created!')

# %%
test_data = pd.read_csv('Test_data.csv')
test_data.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2016     2016           US     National
# 1       2016     2016           US     National
# 2       2016     2016           US     National
# 3       2016     2016           US     National
# 4       2016     2016           US     National
#
#                                    Datasource                    Topic  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                                             Question Data_Value_Type  \
# 0  Percent of adults aged 18 years and older who ...           Value
# 1  Percent of adults aged 18 years and older who ...           Value
# ...

# %% [markdown]
# # Data Leakage

# %%
lake_pred = pd.DataFrame()
lake_pred['prediction'] = (test_data['Low_Confidence_Limit'] + test_data['High_Confidence_Limit '])/2
lake_pred
# Out:
#       prediction
# 0      35.200000
# 1      41.050000
# 2      29.300000
# 3      34.650000
# 4      34.250000
# ...          ...
# 4631   36.188482
# 4632   37.471912
# 4633   30.042218
# 4634   44.573669
# 4635   32.683097
#
# [4636 rows x 1 columns]

# %%
lake_pred.to_csv('lake_mean_pred.csv', index = False)

# %% [markdown]
# RMSE : 0.5794  Muy bien para sólo haber utilizado data leak

# %% [markdown]
# # EDA

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52345 entries, 0 to 52344
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  52345 non-null  int64
#  1   YearEnd                    52345 non-null  int64
#  2   LocationAbbr               52345 non-null  object
#  3   LocationDesc               52345 non-null  object
#  4   Datasource                 52345 non-null  object
#  5   Topic                      52345 non-null  object
#  6   Question                   52345 non-null  object
#  7   Data_Value_Type            52345 non-null  object
#  8   Data_Value                 52345 non-null  float64
#  9   Low_Confidence_Limit       52345 non-null  float64
#  10  High_Confidence_Limit      52345 non-null  float64
#  11  Sample_Size                52345 non-null  float64
#  12  Total                      1801 non-null   object
# ...

# %% [markdown]
# Hay columnas que no se ocuparán, por ejemplo aquellas con un solo valor unico, o aquellas con muchos valores nulos.

# %%
columns = list(train_data.columns)
columns
# Out:
# ['YearStart',
#  'YearEnd',
#  'LocationAbbr',
#  'LocationDesc',
#  'Datasource',
#  'Topic',
#  'Question',
#  'Data_Value_Type',
#  'Data_Value',
#  'Low_Confidence_Limit',
#  'High_Confidence_Limit ',
#  'Sample_Size',
#  'Total',
#  'Age(years)',
#  'Education',
#  'Gender',
#  'Income',
#  'Race/Ethnicity',
#  'GeoLocation',
#  'ClassID',
#  'TopicID',
#  'QuestionID',
#  'DataValueTypeID',
#  'LocationID',
#  'StratificationCategory1',
#  'Stratification1',
#  'StratificationCategoryId1',
#  'StratificationID1',
#  'Class']

# %%
# Eliminar aquellas columnas con un solo valor
for col in columns:
    if train_data[col].nunique() == 1:
        print(col)
        del train_data[col]
# Out:
# Datasource
# Data_Value_Type
# Total
# DataValueTypeID

# %%
train_data
# Out:
#        YearStart  YearEnd LocationAbbr   LocationDesc  \
# 0           2011     2011           AL        Alabama
# 1           2011     2011           AL        Alabama
# 2           2011     2011           AL        Alabama
# 3           2011     2011           AL        Alabama
# 4           2011     2011           AL        Alabama
# ...          ...      ...          ...            ...
# 52340       2014     2014           IN        Arizona
# 52341       2014     2014           OK       Oklahoma
# 52342       2014     2014           NH  New Hampshire
# 52343       2014     2014           WV  West Virginia
# 52344       2014     2014           WY        Wyoming
#
#                                   Topic  \
# 0               Obesity / Weight Status
# 1               Obesity / Weight Status
# 2               Obesity / Weight Status
# 3               Obesity / Weight Status
# 4               Obesity / Weight Status
# ...                                 ...
# ...

# %%
(train_data.YearStart == train_data.YearEnd).all()
# Out:
# True

# %%
del train_data['YearEnd']

# %%
train_data.nunique()
# Out:
# YearStart                        4
# LocationAbbr                    55
# LocationDesc                    55
# Topic                            3
# Question                         9
# Data_Value                   20801
# Low_Confidence_Limit         20839
# High_Confidence_Limit        20887
# Sample_Size                  25919
# Age(years)                       6
# Education                        4
# Gender                           2
# Income                           7
# Race/Ethnicity                   8
# GeoLocation                     54
# ClassID                          3
# TopicID                          3
# QuestionID                       9
# LocationID                   15946
# StratificationCategory1          6
# Stratification1                 28
# StratificationCategoryId1        6
# StratificationID1               28
# Class                            3
# dtype: int64

# %%
train_data = train_data[['YearStart', 'LocationAbbr', 'Low_Confidence_Limit', 'High_Confidence_Limit ', 'Sample_Size', 'TopicID', 'QuestionID', 'StratificationID1', 'Data_Value' ]]

# %%
train_data
# Out:
#        YearStart LocationAbbr  Low_Confidence_Limit  High_Confidence_Limit   \
# 0           2011           AL             30.500000               33.500000
# 1           2011           AL             29.900000               34.700000
# 2           2011           AL             30.000000               33.600000
# 3           2011           AL             29.900000               37.600000
# 4           2011           AL             30.200000               35.600000
# ...          ...          ...                   ...                     ...
# 52340       2014           IN             31.691960               55.396734
# 52341       2014           OK             43.040983               52.881966
# 52342       2014           NH              9.617520               36.132657
# 52343       2014           WV             40.313500               64.446413
# 52344       2014           WY             15.751715               18.584689
#
# ...

# %%
#cat_ord_features = ['YearStart']
cat_nom_features = ['LocationAbbr', 'TopicID', 'QuestionID', 'StratificationID1']
num_features = ['Low_Confidence_Limit', 'High_Confidence_Limit ', 'Sample_Size']

# %% [markdown]
# # Data

# %%
X = train_data.iloc[:,:-1]
y = train_data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13)

# %% [markdown]
# ## PipeLine

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

#categorical_ord_pipe = Pipeline([
#    ('onehot', OrdinalEncoder(handle_unknown='use_encoded_value'))
# ])
categorical_nom_pipe = Pipeline([
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

preprocessing = ColumnTransformer(
    [#('ord_cat', categorical_ord_pipe, cat_ord_features),
     ('nom_cat', categorical_nom_pipe, cat_nom_features)])

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rf = Pipeline([
    ('preprocess', preprocessing),
    ('classifier', RandomForestRegressor(random_state=13))
])
rf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-0064952711ef> in <module>
#       4     ('classifier', RandomForestRegressor(random_state=13))
#       5 ])
# ----> 6 rf.fit(X_train, y_train)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     333             if self._final_estimator != 'passthrough':
#     334                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 335                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     336
#     337         return self
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     384             # parallel_backend contexts set at a higher level,
#     385             # since correctness does not rely on using threads.
# ...

# %%
rf.score(X_test, y_test)

# %%
importances = rf.steps[1][1].feature_importances_
indices = np.argsort(importances)[::-1]
indices
# Print the feature ranking
print("Feature ranking:")

for f in range(X_train.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

# %%
test_rf = test_data[X_train.columns]
submit(rf.predict(test_rf), 'rf_predict')

# %% [markdown]
# 3.5 Muy maal

# %% [markdown]
# ## High and Low Limits

# %%
limits_data = train_data[['Low_Confidence_Limit', 'High_Confidence_Limit ', 'Data_Value']]
limits_data
# Out:
#        Low_Confidence_Limit  High_Confidence_Limit   Data_Value
# 0                 30.500000               33.500000   32.000000
# 1                 29.900000               34.700000   32.300000
# 2                 30.000000               33.600000   31.800000
# 3                 29.900000               37.600000   33.600000
# 4                 30.200000               35.600000   32.800000
# ...                     ...                     ...         ...
# 52340             31.691960               55.396734   43.148744
# 52341             43.040983               52.881966   47.997376
# 52342              9.617520               36.132657   19.675684
# 52343             40.313500               64.446413   52.539239
# 52344             15.751715               18.584689   17.162706
#
# [52345 rows x 3 columns]

# %%
X_limits = limits_data.iloc[:,:-1]
y_limits = limits_data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_limits, y_limits, test_size=0.2, random_state=13)

# %% [markdown]
# # Xgboost

# %%
import xgboost as xgb
xgb_model = xgb.XGBRegressor()

# %%
xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
pd.DataFrame(xgb_model.feature_importances_.reshape(1, -1), columns=X_train.columns)
# Out:
#    Low_Confidence_Limit  High_Confidence_Limit
# 0              0.662691                0.337309

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_train, xgb_model.predict(X_train)))
# Out:
# 0.014923480595058783

# %%
xgb_pred = xgb_model.predict(X_test)
print(mean_squared_error(y_test, xgb_pred))
# Out:
# 0.02560227376055583

# %%
submit(xgb_model.predict(test_data[X_train.columns]), 'xgb_predict')
# Out:
# 'Csv Created!'

# %% [markdown]
# ## Linear Regression
# Quiero buscar alguna relacion lineal entre estas variables, ya que los limites pueden comunicar mucho

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)

# %%
lr.score(X_test, y_test)

# %%
submit(lr.predict(test_data[X_train.columns]), 'lr_predict')

# %% [markdown]
# 0.2869 en Dphi

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(100)
ridge.fit(X_train, y_train)

# %%
ridge.score(X_test, y_test)

# %% [markdown]
# ## Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
rf_limit = RandomForestRegressor()
rf_limit.fit(X_train, y_train)

# %%
rf_limit.score(X_test, y_test)

# %%
submit(rf_limit.predict(test_data[X_train.columns]), 'rf_predict1')

# %% [markdown]
# 0.0562 Pretty good, se puede mejorar si veo los hyperparametros //
# 0.0531 con todo los datos

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
params = {
    'n_estimators' : [500],
    'max_depth' : [100]
}

grid_rf = GridSearchCV(RandomForestRegressor(), params)

# %%
grid_rf.best_params_, grid_rf.best_score_

# %%
from sklearn.ensemble import RandomForestRegressor
rf_limit = RandomForestRegressor(max_depth = 10, n_estimators = 200)
rf_limit.fit(X_train, y_train)
rf_limit.score(X_test, y_test)

# %% [markdown]
# Ahora quiero sumar el sample size a las variables

# %% [markdown]
# # Sample Size

# %%
sz = train_data[['Low_Confidence_Limit', 'High_Confidence_Limit ', 'Sample_Size', 'Data_Value']]
sz
# Out:
#        Low_Confidence_Limit  High_Confidence_Limit   Sample_Size  Data_Value
# 0                 30.500000               33.500000  7304.000000   32.000000
# 1                 29.900000               34.700000  2581.000000   32.300000
# 2                 30.000000               33.600000  4723.000000   31.800000
# 3                 29.900000               37.600000  1153.000000   33.600000
# 4                 30.200000               35.600000  2402.000000   32.800000
# ...                     ...                     ...          ...         ...
# 52340             31.691960               55.396734   159.871859   43.148744
# 52341             43.040983               52.881966   825.537695   47.997376
# 52342              9.617520               36.132657    55.139452   19.675684
# 52343             40.313500               64.446413   130.535869   52.539239
# 52344             15.751715               18.584689  5819.000000   17.162706
#
# [52345 rows x 4 columns]

# %%
X_sz = sz.iloc[:,:-1]
y_sz = sz.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_sz, y_sz, test_size=0.2, random_state=13)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_sz = RandomForestRegressor()
rf_sz.fit(X_sz, y_sz)

# %%
rf_sz.score(X_test, y_test)

# %%
submit(rf_sz.predict(test_data[X_train.columns]), 'rfSampleSize_predict1')

# %%
from sklearn.svm import SVR
svr = SVR(kernel = 'linear')
svr.fit(X_train, y_train)

# %%
svr.score(X_test, y_test)

# %%
submit(svr.predict(test_data[X_train.columns]), 'SVR_predict1')

# %%
plt.Figure()
sns.displot(data = sz, x= 'Low_Confidence_Limit')
sns.displot(data = sz, x= 'High_Confidence_Limit ')
sns.displot(data = sz, x= 'Data_Value')
plt.show()
